# %%
from pegawai import ambil_pegawai_dari_smartoffice

data = ambil_pegawai_dari_smartoffice()
golongans=data["golonganId"]
print(golongans)
# Out:
# icicicicicicicicicicicicicicicicicicicicicicicicicicicicicicicic||||||||||||||||||||||||||||||||                                resultresultresultresultresultresultresultresultresultresultresultresultresultresultresultresultresultresultresultresultresultresultresultresultresultresultresultresultresultresultresultresult:::::::::::::::::::::::::::::    :::                                                                                                            id    idid        idid    idididididididididididididididid
# ididididididid
# id
#
#
# ididid
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#             0                                                                                                                                                0            0                                                0                                    0                        00            0000  0000000  00000     0000   0000   0                10      10         10            9        9            5121110  12   912
#
# 911107
# 585105
# 858
# 11885
#
# 8
# 10
#
# 9ic9
#
#
# ic
#
# ic
#
#
# ic
#
#
#
#
#
# ic
#
#
# ic
#
# icicicic
#
#
# icicicicic|||icicicicicicic|ic|icicic|icic|ic||icic||ic|||| ||  |  ||||||||   || |||      result| result result result  result   result  resultresult   result  result resultresultresult:result result:resultresultresult::resultresult:resultresult:result:result:resultresultresult::result:result:resultresult:    ::result::    :    ::        :    :    ::    ::        ::    :        :            :    id:id    idid    id    id    id                ididid        idid            idididid    id
#
#
# id
#
#
# idid
# id
# ididid
#
# id
# id
# idid
# id
#
#
# idid
#
#
#                         id
#
#
#
#
#
#
#
#
#
#
# 0
# 0            000            0            0000            0
#                                                 00                        0            00                              0   0   0         0   0      0000  0            0          00   004   64   8   467   94      7      12         512  7   010     566
#
#
#
# 8
#
#
# 5
#
#
# 76
# 8587510
#
#
#
#
# 49
# 10ic  icic
# icic
# icic
# icicic
# ic
#
#
#
#
#
# icic
#
# ic
# icic|ic|ic||||ic
# 11|||ic|icicicicic|icicic||ic|||ic|   |  | ic  | |
# | |||| ||    | result|result result resultresultresult |resultresult  result  ic  result result resultresult ::result resultresult :result:::result :resultresult::resultresultresultresultresult:result|    result:result:result:    :result    :::            :result    ::        ::::::        :id     :idid:    :    id    id    id    :    id        id    id                    idid
#
# id        idresult
#
# id    id
#
# id
# ididididid
# idid
# ididid
#
#             id                        :
#
# id
# idid                                    id
#
#
#
#
#
#
#
#
# 0
#
#
#
#                         00
#
# 0
# 0            0            0
#                                                             0                                      0            00                                         0              0id      0            0  000            00   120000   00   1005   0   0   8410
#       012              5   0
#      9         4
# 5
#       44
# 4  5
#
#
# 295113
# 5   541155
#
# ic
# 5ic5ic
#
# 5ic
#
# 0icicic
# 10
#
#
#
# ic5
#
# ic
#
#
#
#
# ic|ic|ic
#
# |ic|  icic||ic|ic
# icic|ic
# icicicicicic| ic|| |ic12ic || ||   ||||ic ic||||| |result  |
# result ||result   result resultresultresult   |result|     result:  resultresulticresult:result  :resultresultresult:result::result:result resultresultresult: result:resultresultresult    result:|:result::    result:    :::            ::::    :result    resultid:    ::::     :        id        id    :        idid                id    :
# id    id:    id
# resultididididid
# ididid
#
# ididid
# idid    id
#             id
# idid
# id
# id:
#
#
#
#
# id
#
#
#
#
# id
#
#
# id
#
#
# 00
#
#                                     0            0
#             00
#             0
# 00            id               0               000   00                  00   0000            0   00            00      4
# 0   05            4   7      905              0   4      640
#
#    9   55
# 54
# 594   4
#
# 56105   54
#
# 710
# ic   ic
# 0
# 54
#
# ic
# ic
#
#
# 4
#
# icic
#
#
#
#
#
# 4|icic
# ic9|icic
#    ic
# |icicicic|ic|
# icic|icicic
# icic ic|ic|
# ||| ic6| |ic|||ic| ic||  ||||result||   | resultresult
#  ic|    | | |result      result: resultresultresult resultresult: resultic:resultresultresultresult | result  result:resultresultresultresult:resultresult    :result::result:    :result:|    result::::result :result    :result:    :::::    :id    :    id:                         id    :    ::resultid    :        id                id
# id    idid
# ididid
# idresultid                id:
# ididid
#     idid
# idididid
#
# id
#
#
#
#
# :
#             ididid
#
# id
#
#
#
# id
#
#
#
#             0
#
#                             0            0
#
#
# id                        0            0
# 0                           00            0000id0  0   0                                    0
# 00  00            00     040   0        0
#    412         000                11            50      10
#    551155
#    595
# 5   1210
#    06559
# 5   4ic5
#
#
#
#
#
# ic6
# 09
#
# ic
#
#
# 57
# 4ic
#
# ic
#
#
# 9
# ic|icicic   |
# icicic
# |icicicicic|
#
#
# icic|ic5icicic
# |ic |5 |ic||||ic | ||||ic|ic||ic |
# ||
# | icresultresult   || result   result     | | | ic resultic: result| :  result:resultresult:resultresultresultresultresultresultresultresultresult resultresultresult |result :|    : resultresultresult        result    ::::::::::::result:result :    :result:     result:::ididid:    id                                        :        :idresult        :idresult            :
#
#
#     id
# idididididididid
# id    idid    id:idid
#     :id            idid
# id            id
#
#
#
#
#
#
#
#
#             id
# id
#
#
#
# id
#             id0
#
# 0
# 0
# 0
#                                     00
# id
# 0            id            0
#                                     00            00000      0            000            00
#                00
#                504404                  54         0   0   0                  40   4
#             0
#    4
#
# 54444
#
# 4   4   044
# 4   443
#    ic30   2
# ic4
# icic
#
#
# icic
#
#    3
# ic
#
#
#
# 5
# 3
# 3ic|ic
#
# 3|
# ic|icic|icic||3ic
# |
# |
#
#  |3
#  |||
# | | |   resultresult  result
#     resultresultresult result:resultresult::resultresultresult:resultresult:result::    ::    :    ::        ::    :    id            idid        idid        id
#
# ididididid
# idid
#
#
# idid
#
#
#
#
#
#
# 0
#
# 0                                                            000                                       0               00000      3   0000   3               33
#    3   3
#    3333
# 3
#
# 66
# 3
# 5
# 0       NaN
# 1       NaN
# 2      12.0
# 3      10.0
# 4      10.0
#        ...
# 250     NaN
# 251     NaN
# 252     NaN
# 253     NaN
# 254     NaN
# Name: golonganId, Length: 255, dtype: float64
